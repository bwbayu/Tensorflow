# %% [markdown]
# <a href="https://colab.research.google.com/github/bwbayu/Tensorflow/blob/main/cousera_course/House_Pricing_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Assignment: Housing Prices
#
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# Imagine that house pricing is as easy as:
#
# A house has a base cost of 50k, and every additional bedroom adds a cost of 50k. This will make a 1 bedroom house cost 100k, a 2 bedroom house cost 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import random
import os

# %%
def reset_random_seeds():
   os.environ['PYTHONHASHSEED']=str(2)
   tf.random.set_seed(2)
   np.random.seed(2)
   random.seed(2)
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)
reset_random_seeds()

# %%
# create input vector
xs = np.array([1, 2, 3, 4, 5, 6], dtype=float)

# create output vector
ys = np.array([1, 1.5, 2, 2.5, 3, 3.5], dtype=float)

# create model
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=1)) # input layer
model.add(tf.keras.layers.Dense(1, activation='linear')) # output layer with activation function linear for regression task

# compile
model.compile(loss=tf.keras.losses.MSE, # loss function MSE -> Mean Squared Error, evaluation metrics for regression task
              optimizer = tf.keras.optimizers.SGD()) # optimizer SGD

# %%
# fit model
history = model.fit(xs, ys, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 371ms/step - loss: 0.7036
# Epoch 2/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3466
# Epoch 3/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1813
# Epoch 4/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1046
# Epoch 5/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0689
# Epoch 6/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0523
# Epoch 7/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0444
# Epoch 8/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0406
# Epoch 9/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0387
# Epoch 10/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0377
# Epoch 11/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0371
# Epoch 12/1000
# ...

# %%
# plot model
pd.DataFrame(history.history).plot()
plt.xlabel("epochs")
plt.ylabel("loss/error")
# Out:
# Text(0, 0.5, 'loss/error')

# %%
# predict new data
new_x = 7.0
prediction = model.predict([new_x])[0]
print(prediction)
# Out:
# 1/1 [==============================] - 0s 59ms/step
# [4.007442]
